# %%
from unlabeled_extrapolation.datasets import wilds
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

import importlib
importlib.reload(wilds)
# Out:
# <module 'unlabeled_extrapolation.datasets.wilds' from '/home/t-anakumar/transfer_learning/unlabeled_extrapolation/datasets/wilds.py'>

# %%
train_transform = transforms.Compose([
    transforms.Resize(size=224)
])
waterbirds_train = wilds.WILDS(dataset_name='waterbirds-background', split='train', download='true', root='/home/t-anakumar/wilds/data/', transform=train_transform, return_meta=True)

# %%
# Test that the label matches up with the appropriate entry in the metadata.
for i in range(4000):
    x, y, z = waterbirds_train[i]
    plt.imshow(x)
    print(y,z)
    assert(y == z[1])
# Out:
# tensor(1) tensor([1, 1, 1])
# tensor(1) tensor([1, 1, 1])
# tensor(1) tensor([1, 1, 1])
# tensor(1) tensor([1, 1, 1])
# tensor(1) tensor([1, 1, 1])
# tensor(1) tensor([1, 1, 1])
# tensor(1) tensor([1, 1, 1])
# tensor(1) tensor([1, 1, 1])
# tensor(1) tensor([1, 1, 1])
# tensor(1) tensor([1, 1, 1])
# tensor(1) tensor([1, 1, 1])
# tensor(1) tensor([1, 1, 1])
# tensor(1) tensor([1, 1, 1])
# tensor(0) tensor([0, 1, 1])
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
#       3 plt.imshow(x)
#       4 print(y,z)
# ----> 5 assert(y == z[1])
#
# AssertionError:
