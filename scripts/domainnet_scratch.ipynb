# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../datasets')
import matplotlib.pyplot as plt
import domainnet as dn

# %%
dataset = dn.DomainNet('sketch', 'test')

# %%
len(dataset)
# Out:
# 20916

# %%
idx = 300
data = dataset[idx]
plt.imshow(data[0])
print(data[1])
# Out:
# 4
